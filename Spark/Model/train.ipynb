# %% [markdown]
# Notebook for model training.

# %%
from keras import optimizers
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout, GRU
from pyspark.ml.evaluation import RegressionEvaluator
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Using TensorFlow backend.
# </div>

# %%
# %run ../utils

# %%
train_transformed = spark.sql("select * from train_transformed")
validation_transformed = spark.sql("select * from validation_transformed")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
train_x, train_y = prepare_collected_data(train_transformed.select('serie', 'sales').collect())
validation_x, validation_y = prepare_collected_data(validation_transformed.select('serie', 'sales').collect())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
n_label = 1
serie_size = len(train_x[0])
n_features = len(train_x[0][0])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# hyperparameters
epochs = 80
batch = 512
lr = 0.001

# design network
model = Sequential()
model.add(GRU(40, input_shape=(serie_size, n_features)))
model.add(Dense(10, kernel_initializer='glorot_normal', activation='relu'))
model.add(Dense(n_label))
model.summary()

adam = optimizers.Adam(lr)
model.compile(loss='mae', optimizer=adam, metrics=['mse', 'msle'])

history = model.fit(train_x, train_y, epochs=epochs, batch_size=batch, validation_data=(validation_x, validation_y), verbose=2, shuffle=False)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">_________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# gru_1 (GRU)                  (None, 40)                5760
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                410
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 11
# =================================================================
# Total params: 6,181
# Trainable params: 6,181
# Non-trainable params: 0
# _________________________________________________________________
# Train on 357767 samples, validate on 84002 samples
# Epoch 1/80
#  - 101s - loss: 28.6839 - mean_squared_error: 1420.6339 - mean_squared_logarithmic_error: 1.3419 - val_loss: 23.1445 - val_mean_squared_error: 883.1499 - val_mean_squared_logarithmic_error: 0.3308
# Epoch 2/80
#  - 85s - loss: 22.9642 - mean_squared_error: 866.7181 - mean_squared_logarithmic_error: 0.3348 - val_loss: 23.1369 - val_mean_squared_error: 878.5598 - val_mean_squared_logarithmic_error: 0.3314
# Epoch 3/80
#  - 92s - loss: 22.9599 - mean_squared_error: 865.4249 - mean_squared_logarithmic_error: 0.3349 - val_loss: 23.1344 - val_mean_squared_error: 878.3399 - val_mean_squared_logarithmic_error: 0.3313
# Epoch 4/80
#  - 89s - loss: 22.9561 - mean_squared_error: 865.0994 - mean_squared_logarithmic_error: 0.3346 - val_loss: 23.1005 - val_mean_squared_error: 877.8860 - val_mean_squared_logarithmic_error: 0.3298
# Epoch 5/80
#  - 86s - loss: 22.8785 - mean_squared_error: 860.0629 - mean_squared_logarithmic_error: 0.3313 - val_loss: 22.9390 - val_mean_squared_error: 871.1308 - val_mean_squared_logarithmic_error: 0.3231
# Epoch 6/80
#  - 91s - loss: 22.7296 - mean_squared_error: 846.0763 - mean_squared_logarithmic_error: 0.3267 - val_loss: 22.8353 - val_mean_squared_error: 860.0277 - val_mean_squared_logarithmic_error: 0.3201
# Epoch 7/80
#  - 86s - loss: 22.5995 - mean_squared_error: 833.0933 - mean_squared_logarithmic_error: 0.3226 - val_loss: 22.7683 - val_mean_squared_error: 854.9302 - val_mean_squared_logarithmic_error: 0.3176
# Epoch 8/80
#  - 83s - loss: 22.5242 - mean_squared_error: 824.5215 - mean_squared_logarithmic_error: 0.3205 - val_loss: 22.7170 - val_mean_squared_error: 850.1726 - val_mean_squared_logarithmic_error: 0.3160
# Epoch 9/80
#  - 89s - loss: 22.4761 - mean_squared_error: 818.8918 - mean_squared_logarithmic_error: 0.3191 - val_loss: 22.6777 - val_mean_squared_error: 846.8243 - val_mean_squared_logarithmic_error: 0.3147
# Epoch 10/80
#  - 87s - loss: 22.4375 - mean_squared_error: 814.6833 - mean_squared_logarithmic_error: 0.3180 - val_loss: 22.6431 - val_mean_squared_error: 843.9936 - val_mean_squared_logarithmic_error: 0.3137
# Epoch 11/80
#  - 96s - loss: 22.4076 - mean_squared_error: 811.5017 - mean_squared_logarithmic_error: 0.3171 - val_loss: 22.6092 - val_mean_squared_error: 841.3331 - val_mean_squared_logarithmic_error: 0.3128
# Epoch 12/80
#  - 96s - loss: 22.3828 - mean_squared_error: 808.9366 - mean_squared_logarithmic_error: 0.3165 - val_loss: 22.5758 - val_mean_squared_error: 838.6071 - val_mean_squared_logarithmic_error: 0.3119
# Epoch 13/80
#  - 88s - loss: 22.3595 - mean_squared_error: 806.6048 - mean_squared_logarithmic_error: 0.3158 - val_loss: 22.5443 - val_mean_squared_error: 836.2543 - val_mean_squared_logarithmic_error: 0.3110
# Epoch 14/80
#  - 84s - loss: 22.3335 - mean_squared_error: 804.2019 - mean_squared_logarithmic_error: 0.3151 - val_loss: 22.5170 - val_mean_squared_error: 834.6860 - val_mean_squared_logarithmic_error: 0.3102
# Epoch 15/80
#  - 88s - loss: 22.3078 - mean_squared_error: 801.9074 - mean_squared_logarithmic_error: 0.3144 - val_loss: 22.4939 - val_mean_squared_error: 833.1340 - val_mean_squared_logarithmic_error: 0.3096
# Epoch 16/80
#  - 91s - loss: 22.2855 - mean_squared_error: 799.8575 - mean_squared_logarithmic_error: 0.3138 - val_loss: 22.4681 - val_mean_squared_error: 830.6987 - val_mean_squared_logarithmic_error: 0.3091
# Epoch 17/80
#  - 105s - loss: 22.2555 - mean_squared_error: 797.3632 - mean_squared_logarithmic_error: 0.3129 - val_loss: 22.4433 - val_mean_squared_error: 829.3724 - val_mean_squared_logarithmic_error: 0.3083
# Epoch 18/80
#  - 89s - loss: 22.2241 - mean_squared_error: 794.4451 - mean_squared_logarithmic_error: 0.3120 - val_loss: 22.4238 - val_mean_squared_error: 828.3610 - val_mean_squared_logarithmic_error: 0.3077
# Epoch 19/80
#  - 86s - loss: 22.1858 - mean_squared_error: 791.3544 - mean_squared_logarithmic_error: 0.3109 - val_loss: 22.4009 - val_mean_squared_error: 826.5667 - val_mean_squared_logarithmic_error: 0.3070
# Epoch 20/80
#  - 78s - loss: 22.1279 - mean_squared_error: 786.9665 - mean_squared_logarithmic_error: 0.3090 - val_loss: 22.3877 - val_mean_squared_error: 825.6867 - val_mean_squared_logarithmic_error: 0.3064
# Epoch 21/80
#  - 85s - loss: 22.0344 - mean_squared_error: 778.1406 - mean_squared_logarithmic_error: 0.3062 - val_loss: 22.3850 - val_mean_squared_error: 822.8025 - val_mean_squared_logarithmic_error: 0.3066
# Epoch 22/80
#  - 49s - loss: 21.9485 - mean_squared_error: 769.3882 - mean_squared_logarithmic_error: 0.3037 - val_loss: 22.2967 - val_mean_squared_error: 811.8785 - val_mean_squared_logarithmic_error: 0.3043
# Epoch 23/80
#  - 34s - loss: 21.8798 - mean_squared_error: 762.6545 - mean_squared_logarithmic_error: 0.3015 - val_loss: 22.1974 - val_mean_squared_error: 802.2144 - val_mean_squared_logarithmic_error: 0.3014
# Epoch 24/80
#  - 36s - loss: 21.8135 - mean_squared_error: 756.7541 - mean_squared_logarithmic_error: 0.2993 - val_loss: 22.1282 - val_mean_squared_error: 795.3294 - val_mean_squared_logarithmic_error: 0.2995
# Epoch 25/80
#  - 35s - loss: 21.7653 - mean_squared_error: 751.2109 - mean_squared_logarithmic_error: 0.2979 - val_loss: 22.0109 - val_mean_squared_error: 785.7035 - val_mean_squared_logarithmic_error: 0.2960
# Epoch 26/80
#  - 35s - loss: 21.7037 - mean_squared_error: 746.6600 - mean_squared_logarithmic_error: 0.2957 - val_loss: 21.8721 - val_mean_squared_error: 775.3263 - val_mean_squared_logarithmic_error: 0.2913
# Epoch 27/80
#  - 37s - loss: 21.6012 - mean_squared_error: 737.9825 - mean_squared_logarithmic_error: 0.2930 - val_loss: 21.7712 - val_mean_squared_error: 764.7906 - val_mean_squared_logarithmic_error: 0.2890
# Epoch 28/80
#  - 35s - loss: 21.5449 - mean_squared_error: 732.6404 - mean_squared_logarithmic_error: 0.2917 - val_loss: 21.6957 - val_mean_squared_error: 755.6018 - val_mean_squared_logarithmic_error: 0.2878
# Epoch 29/80
#  - 35s - loss: 21.4949 - mean_squared_error: 728.2186 - mean_squared_logarithmic_error: 0.2904 - val_loss: 21.6519 - val_mean_squared_error: 750.7259 - val_mean_squared_logarithmic_error: 0.2869
# Epoch 30/80
#  - 36s - loss: 21.4596 - mean_squared_error: 725.1086 - mean_squared_logarithmic_error: 0.2895 - val_loss: 21.6329 - val_mean_squared_error: 747.9031 - val_mean_squared_logarithmic_error: 0.2867
# Epoch 31/80
#  - 35s - loss: 21.4339 - mean_squared_error: 722.8224 - mean_squared_logarithmic_error: 0.2889 - val_loss: 21.6199 - val_mean_squared_error: 745.7732 - val_mean_squared_logarithmic_error: 0.2867
# Epoch 32/80
#  - 38s - loss: 21.4146 - mean_squared_error: 721.1167 - mean_squared_logarithmic_error: 0.2885 - val_loss: 21.6097 - val_mean_squared_error: 744.3025 - val_mean_squared_logarithmic_error: 0.2867
# Epoch 33/80
#  - 35s - loss: 21.3966 - mean_squared_error: 719.5868 - mean_squared_logarithmic_error: 0.2881 - val_loss: 21.6125 - val_mean_squared_error: 744.4376 - val_mean_squared_logarithmic_error: 0.2869
# Epoch 34/80
#  - 34s - loss: 21.3816 - mean_squared_error: 718.4648 -

# %%
model_path = '/dbfs/user/model1.json'
weights_path = '/dbfs/user/weights1.npy'
save_model(model_path, weights_path, model)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
predictions = model.predict(validation_x)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
import pandas as pd
ids = validation_y
df = pd.DataFrame(ids, columns=['label'])
df['sales'] = predictions
df_predictions = spark.createDataFrame(df)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
rmse_evaluator = RegressionEvaluator(labelCol="label", predictionCol="sales", metricName="rmse")
mse_evaluator = RegressionEvaluator(labelCol="label", predictionCol="sales", metricName="mse")
mae_evaluator = RegressionEvaluator(labelCol="label", predictionCol="sales", metricName="mae")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
validation_rmse = rmse_evaluator.evaluate(df_predictions)
validation_mse = mse_evaluator.evaluate(df_predictions)
validation_mae = mae_evaluator.evaluate(df_predictions)
print("RMSE: %f, MSE: %f, MAE: %f" % (validation_rmse, validation_mse, validation_mae))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">RMSE: 25.569828, MSE: 653.816128, MAE: 20.075652
# </div>
