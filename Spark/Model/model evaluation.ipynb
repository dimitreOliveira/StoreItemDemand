# %%
# %run ../utils

# %%
import pandas as pd
from pyspark.ml.evaluation import RegressionEvaluator
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
rmse_evaluator = RegressionEvaluator(labelCol="label", predictionCol="sales", metricName="rmse")
mse_evaluator = RegressionEvaluator(labelCol="label", predictionCol="sales", metricName="mse")
mae_evaluator = RegressionEvaluator(labelCol="label", predictionCol="sales", metricName="mae")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Load model
model_path = '/dbfs/user/model7.json'
weights_path = '/dbfs/user/weights7.npy'
model = load_model(model_path, weights_path)
# Load validation data set
validation_transformed = spark.sql("select * from validation_transformed")
# Get validation series and labels
validation_x, validation_y = prepare_collected_data(validation_transformed.select('serie', 'sales').collect())
# Make predictions
predictions = model.predict(validation_x)
# Turn predctions into spark dataframe
df = pd.DataFrame(validation_y, columns=['label'])
df['sales'] = predictions
df_predictions = spark.createDataFrame(df)
# Evaluate model
validation_rmse = rmse_evaluator.evaluate(df_predictions)
validation_mse = mse_evaluator.evaluate(df_predictions)
validation_mae = mae_evaluator.evaluate(df_predictions)
print("RMSE: %f, MSE: %f, MAE: %f" % (validation_rmse, validation_mse, validation_mae))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">RMSE: 7.638403, MSE: 58.345194, MAE: 5.858985
# </div>

# %%
# Load model
model_path = '/dbfs/user/model8.json'
weights_path = '/dbfs/user/weights8.npy'
model = load_model(model_path, weights_path)
# Load validation data set
validation_transformed = spark.sql("select * from validation_transformed_10")
# Get validation series and labels
validation_x, validation_y = prepare_collected_data(validation_transformed.select('serie', 'sales').collect())
# Make predictions
predictions = model.predict(validation_x)
# Turn predctions into spark dataframe
df = pd.DataFrame(validation_y, columns=['label'])
df['sales'] = predictions
df_predictions = spark.createDataFrame(df)
# Evaluate model
validation_rmse = rmse_evaluator.evaluate(df_predictions)
validation_mse = mse_evaluator.evaluate(df_predictions)
validation_mae = mae_evaluator.evaluate(df_predictions)
print("RMSE: %f, MSE: %f, MAE: %f" % (validation_rmse, validation_mse, validation_mae))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">RMSE: 7.980495, MSE: 63.688299, MAE: 6.099743
# </div>

# %%
# Load model
model_path = '/dbfs/user/model9.json'
weights_path = '/dbfs/user/weights9.npy'
model = load_model(model_path, weights_path)
# Load validation data set
validation_transformed = spark.sql("select * from validation_transformed_15")
# Get validation series and labels
validation_x, validation_y = prepare_collected_data(validation_transformed.select('serie', 'sales').collect())
# Make predictions
predictions = model.predict(validation_x)
# Turn predctions into spark dataframe
df = pd.DataFrame(validation_y, columns=['label'])
df['sales'] = predictions
df_predictions = spark.createDataFrame(df)
# Evaluate model
validation_rmse = rmse_evaluator.evaluate(df_predictions)
validation_mse = mse_evaluator.evaluate(df_predictions)
validation_mae = mae_evaluator.evaluate(df_predictions)
print("RMSE: %f, MSE: %f, MAE: %f" % (validation_rmse, validation_mse, validation_mae))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">RMSE: 8.683186, MSE: 75.397715, MAE: 6.554063
# </div>

# %%
# Load model
model_path = '/dbfs/user/model10.json'
weights_path = '/dbfs/user/weights10.npy'
model = load_model(model_path, weights_path)
# Load validation data set
validation_transformed = spark.sql("select * from validation_transformed_5")
# Get validation series and labels
validation_x, validation_y = prepare_collected_data(validation_transformed.select('serie', 'sales').collect())
# Make predictions
predictions = model.predict(validation_x)
# Turn predctions into spark dataframe
df = pd.DataFrame(validation_y, columns=['label'])
df['sales'] = predictions
df_predictions = spark.createDataFrame(df)
# Evaluate model
validation_rmse = rmse_evaluator.evaluate(df_predictions)
validation_mse = mse_evaluator.evaluate(df_predictions)
validation_mae = mae_evaluator.evaluate(df_predictions)
print("RMSE: %f, MSE: %f, MAE: %f" % (validation_rmse, validation_mse, validation_mae))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">RMSE: 8.346504, MSE: 69.664136, MAE: 6.315152
# </div>

# %%
# Load model
model_path = '/dbfs/user/model11.json'
weights_path = '/dbfs/user/weights11.npy'
model = load_model(model_path, weights_path)
# Load validation data set
validation_transformed = spark.sql("select * from validation_transformed_10")
# Get validation series and labels
validation_x, validation_y = prepare_collected_data(validation_transformed.select('serie', 'sales').collect())
# Make predictions
predictions = model.predict(validation_x)
# Turn predctions into spark dataframe
df = pd.DataFrame(validation_y, columns=['label'])
df['sales'] = predictions
df_predictions = spark.createDataFrame(df)
# Evaluate model
validation_rmse = rmse_evaluator.evaluate(df_predictions)
validation_mse = mse_evaluator.evaluate(df_predictions)
validation_mae = mae_evaluator.evaluate(df_predictions)
print("RMSE: %f, MSE: %f, MAE: %f" % (validation_rmse, validation_mse, validation_mae))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">RMSE: 8.755076, MSE: 76.651358, MAE: 6.584410
# </div>

# %%
# Load model
model_path = '/dbfs/user/model12.json'
weights_path = '/dbfs/user/weights12.npy'
model = load_model(model_path, weights_path)
# Load validation data set
validation_transformed = spark.sql("select * from validation_transformed_15")
# Get validation series and labels
validation_x, validation_y = prepare_collected_data(validation_transformed.select('serie', 'sales').collect())
# Make predictions
predictions = model.predict(validation_x)
# Turn predctions into spark dataframe
df = pd.DataFrame(validation_y, columns=['label'])
df['sales'] = predictions
df_predictions = spark.createDataFrame(df)
# Evaluate model
validation_rmse = rmse_evaluator.evaluate(df_predictions)
validation_mse = mse_evaluator.evaluate(df_predictions)
validation_mae = mae_evaluator.evaluate(df_predictions)
print("RMSE: %f, MSE: %f, MAE: %f" % (validation_rmse, validation_mse, validation_mae))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">RMSE: 9.394270, MSE: 88.252316, MAE: 7.035780
# </div>
